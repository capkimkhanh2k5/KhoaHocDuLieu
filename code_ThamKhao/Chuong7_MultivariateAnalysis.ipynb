# %%
pip install prince==0.10.3
# Out:
# Requirement already satisfied: prince==0.10.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.10.3)
# Requirement already satisfied: altair<5.0.0,>=4.2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from prince==0.10.3) (4.2.2)
# Requirement already satisfied: pandas<3.0.0,>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from prince==0.10.3) (1.5.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from prince==0.10.3) (1.1.3)
# Requirement already satisfied: entrypoints in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.2->prince==0.10.3) (0.4)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.2->prince==0.10.3) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.2->prince==0.10.3) (4.17.3)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.2->prince==0.10.3) (1.23.4)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5.0.0,>=4.2.2->prince==0.10.3) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas<3.0.0,>=1.4.1->prince==0.10.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas<3.0.0,>=1.4.1->prince==0.10.3) (2022.7.1)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.2->prince==0.10.3) (1.9.3)
# Requirement already satisfied: joblib>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.2->prince==0.10.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.2->prince==0.10.3) (3.1.0)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.2->prince==0.10.3) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5.0.0,>=4.2.2->prince==0.10.3) (0.19.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas<3.0.0,>=1.4.1->prince==0.10.3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->altair<5.0.0,>=4.2.2->prince==0.10.3) (2.1.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: pip3.11 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Principal component analysis (PCA)

# %% [markdown]
# If you're using PCA it is assumed you have a dataframe consisting of numerical continuous variables. In this example we're going to be using the Iris flower dataset.

# %%
import pandas as pd
import prince
from sklearn import datasets

X, y = datasets.load_iris(return_X_y=True)
X = pd.DataFrame(data=X, columns=['Sepal length', 'Sepal width', 'Petal length', 'Petal width'])
y = pd.Series(y).map({0: 'Setosa', 1: 'Versicolor', 2: 'Virginica'})
X.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# The PCA class implements scikit-learn's fit/transform API. It's parameters have to passed at initialisation before calling the fit method.

# %%
pca = prince.PCA(
    n_components=2,
    n_iter=3,
    rescale_with_mean=True,
    rescale_with_std=True,
    copy=True,
    check_input=True,
    engine='sklearn',
    random_state=42
)
pca = pca.fit(X)

# %% [markdown]
# Once the PCA has been fitted, it can be used to extract the row principal coordinates.

# %%
pca.transform(X).head() # same as pca.row_coordinates(X).head()
# Out:
# component         0         1
# 0         -2.264703  0.480027
# 1         -2.080961 -0.674134
# 2         -2.364229 -0.341908
# 3         -2.299384 -0.597395
# 4         -2.389842  0.646835

# %% [markdown]
# Each column stands for a principal component whilst each row stands a row in the original dataset. You can display these projections with the plot_row_coordinates method:

# %%
pca.plot(
    X,
    x_component=0,
    y_component=1,
    #color_by=y,
    show_rows=True,
    show_columns=True
)
# Out:
# alt.LayerChart(...)

# %%
# So sánh với khi không sử dụng PCA
from sklearn.datasets import load_iris
iris = load_iris()

from matplotlib import pyplot as plt

# The indices of the features that we are plotting
x_index = 2
y_index = 0

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.figure(figsize=(5, 4))
plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index])

plt.tight_layout()
plt.show()

# %% [markdown]
# The explained inertia represents the percentage of the inertia each principal component contributes.

# %%
pca.percentage_of_variance_
# Out:
# array([72.96244541, 22.85076179])

# %% [markdown]
# The explained inertia is obtained by dividing the eigenvalues obtained with the SVD by the total inertia, both of which are also accessible.

# %% [markdown]
# You can also obtain the coordinates of eigenvectors in original space.

# %%
pca.eigenvalues_
# Out:
# array([2.91849782, 0.91403047])

# %%
pca.total_inertia_
# Out:
# 4.0

# %%
pca.column_coordinates_
# Out:
# component            0         1
# variable
# Sepal length  0.890169  0.360830
# Sepal width  -0.460143  0.882716
# Petal length  0.991555  0.023415
# Petal width   0.964979  0.064000

# %% [markdown]
# You can also transform row projections back into their original space by using the inverse_transform method.

# %%
pca.inverse_transform(pca.transform(X)).head()
# Out:
#           0         1         2         3
# 0  5.018949  3.514854  1.466013  0.251922
# 1  4.738463  3.030433  1.603913  0.272074
# 2  4.720130  3.196830  1.328961  0.167414
# 3  4.668436  3.086770  1.384170  0.182247
# 4  5.017093  3.596402  1.345411  0.206706

# %%
# compare with first 5 observations of the original data
X.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# # Phân tích tương ứng (Correspondence analysis - CA)

# %%
# Dữ liệu "Relationship of Hair Color to Eye Color of Scottish Schoolchildren"
# http://ce.aut.ac.ir/~shiry/lecture/Advanced%20Machine%20Learning/Manifold_Modern_Multivariate%20Statistical%20Techniques%20-%20Regres.pdf
# page: 662
import pandas as pd
pd.set_option('display.float_format', lambda x: '{:.6f}'.format(x))
X = pd.DataFrame(
    data=[
          [326, 38, 241, 110, 3],
          [688, 116, 584, 188, 4],
          [343, 84, 909, 412, 26],
          [98, 48, 403, 681, 85]
    ],
    columns=pd.Series(['Fair', 'Red', 'Medium', 'Dark', 'Black']),
    index=pd.Series(['Blue', 'Light', 'Medium', 'Dark'])
)
X
# Out:
#         Fair  Red  Medium  Dark  Black
# Blue     326   38     241   110      3
# Light    688  116     584   188      4
# Medium   343   84     909   412     26
# Dark      98   48     403   681     85

# %%
import prince
ca = prince.CA(
    n_components=2,
    n_iter=3,
    copy=True,
    check_input=True,
    engine='auto',
    random_state=42
)
X.columns.rename('Hair color', inplace=True)
X.index.rename('Eye color', inplace=True)
ca = ca.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 12
#      10 X.columns.rename('Hair color', inplace=True)
#      11 X.index.rename('Eye color', inplace=True)
# ---> 12 ca = ca.fit(X)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/prince/ca.py:85, in CA.fit(self, X, y)
#      82 S = sparse.diags(r**-0.5) @ (X - np.outer(r, c)) @ sparse.diags(c**-0.5)
#      84 # Compute SVD on the standardised residuals
# ---> 85 self.svd_ = svd.compute_svd(
#      86     X=S,
#      87     n_components=min(self.n_components, min(X.shape) - 1),
#      88     n_iter=self.n_iter,
#      89     random_state=self.random_state,
#      90     engine=self.engine,
#      91 )
#      93 # Compute total inertia
#      94 self.total_inertia_ = np.einsum("ij,ji->", S, S.T)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/prince/svd.py:45, in compute_svd(X, n_components, n_iter, random_state, engine)
#      41     U, s, V = extmath.randomized_svd(
#      42         X, n_components=n_components, n_iter=n_iter, random_state=random_state
#      43     )
#      44 else:
# ---> 45     raise ValueError("engine has to be one of ('fbpca', 'scipy', 'sklearn')")
#      47 # U, V = extmath.svd_flip(U, V)
#      49 return SVD(U, s, V)
#
# ValueError: engine has to be one of ('fbpca', 'scipy', 'sklearn')

# %%
ca.row_coordinates(X)
# Out:
#                0         1
# Blue   -0.400300 -0.165411
# Light  -0.440708 -0.088463
# Medium  0.033614  0.245002
# Dark    0.702739 -0.133914

# %%
ca.column_coordinates(X)
# Out:
#                0         1
# Fair   -0.543995 -0.173844
# Red    -0.233261 -0.048279
# Medium -0.042024  0.208304
# Dark    0.588709 -0.103950
# Black   1.094388 -0.286437

# %%
ax = ca.plot_coordinates(
    X=X,
    ax=None,
    figsize=(6, 6),
    x_component=0,
    y_component=1,
    show_row_labels=True,
    show_col_labels=True
)
ax.get_figure().savefig('ca_coordinates.svg')

# %%
# k-means clustering
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
from sklearn.cluster import KMeans
from matplotlib import pyplot
# define dataset
X, _ = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=4)
# define the model
model = KMeans(n_clusters=3)
# fit the model
model.fit(X)
# assign a cluster to each example
yhat = model.predict(X)
# retrieve unique clusters
clusters = unique(yhat)
# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1])
# show the plot
pyplot.show()

# %% [markdown]
# # Linear Discriminant Analysis (LDA)

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = datasets.load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names
lda = LinearDiscriminantAnalysis(n_components=2)
X_r2 = lda.fit(X, y).transform(X)
plt.figure()
colors = ['navy', 'turquoise', 'darkorange']
for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r2[y == i, 0], X_r2[y == i, 1], alpha=.8, color=color,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of IRIS dataset')
plt.show()
