# %% [markdown]
# # Bag Of Word Redo
#
# - Viết chương trình dùng thư viện Numpy và các hàm build in của Python để truy vấn văn bản dùng kỹ thuật Bag of Word
#
# ## Input:
#     - Tập văn bản (corpus)
#     - Văn bản test (test doc)
#     - N: số lượng văn bản cần trả lại (= 5)
#     - Stop_words để loại bỏ các từ không cần thiết
#
# ## Output:
#     - Top-1 văn bản giống nhất với test doc trong 3 TH:
#         + Dùng khoảng cách cosine
#         + Dùng khoảng cách euclid
#         + Dùng khoảng cách Manhattan
#
# ## Result:
#     - Hit nếu trả về doc trong top 5 docs của Querry
#     - Mis
#
# # Data:
#     - data.txt sử dụng để xây dựng corpus (docID: .I với nội dung: .W)
#     - query.txt sử dụng để test docs (queryID: .I với nội dung .W)
#     - rel.txt sử dụng nhãn test (queryID: cột 1 với danh sách của docs liên quan: cột 2)
#
# # Yêu cầu:
#     - Báo cáo độ chính xác của 3 hàm KC và phân tích kết quả thực thi
#     - Accuracy = total # của Hit array giữa tất cả các Querries
#     - So sánh độ chính xác dùng và không dùng của loại bỏ và không loại bỏ stop Words

# %% [markdown]
# # Khoảng cách Cosine
#     - Quan tâm đến hướng
#     - Ứng dụng: Tìm kiếm, so sánh, ...
# # Khoảng cách Euclid
#     - Quan tâm đến độ dài
#     - Ứng dụng: Tính toán số học, ...

# %%
import numpy as np

# %% [markdown]
# # Hàm trích xuất ID + văn bản

# %%
def extract_W_sections(filename, capacity="all"):
    """
    Trích xuất các phần .I và .W từ file data
    
    Args:
        filename: Tên file cần đọc
        capacity: Số lượng văn bản cần trả về ("all" hoặc số nguyên)
    
    Returns:
        List ID của các văn bản .I 
        List các văn bản tương ứng .W
    """
    with open(filename, 'r', encoding='utf-8') as f:
        content = f.read()
    
    documents = []
    current_doc = {}
    current_section = None
    current_text = []
    
    for line in content.split('\n'):
        line = line.strip()
        
        if line.startswith('.I'):
            # Lưu document trước (nếu có)
            if current_section == 'W' and current_text:
                current_doc['W'] = ' '.join(current_text)
            if current_doc:
                documents.append(current_doc)
            
            # Bắt đầu document mới và lưu ID
            doc_id = line.split()[1] if len(line.split()) > 1 else ''
            current_doc = {'I': doc_id}
            current_text = []
            current_section = None
            
        elif line.startswith('.W'):
            # Bắt đầu phần văn bản
            if current_section == 'W' and current_text:
                current_doc['W'] = ' '.join(current_text)
            current_section = 'W'
            current_text = []
            
        elif line.startswith('.'):
            # Các section khác (.T, .A, .X)
            if current_section == 'W' and current_text:
                current_doc['W'] = ' '.join(current_text)
                current_text = []
            current_section = line[1]
            
        elif current_section == 'W' and line:
            # Nội dung của section .W
            current_text.append(line)
    
    # Xử lý document cuối cùng
    if current_section == 'W' and current_text:
        current_doc['W'] = ' '.join(current_text)
    if current_doc:
        documents.append(current_doc)
    
    # Trả về ID và văn bản .W
    i_sections = [doc.get('I', '') for doc in documents if 'I' in doc]
    w_sections = [doc.get('W', '') for doc in documents if 'W' in doc]
    
    # Xử lý capacity
    if capacity == "all":
        return i_sections, w_sections
    else:
        return i_sections[:capacity], w_sections[:capacity]

# Sử dụng - SỬA LỖI
corpus_ids, corpus_texts = extract_W_sections('data.txt')  # Trả về tuple (IDs, texts)
print(f"Số lượng văn bản: {len(corpus_texts)} documents")
# Out:
# Số lượng văn bản: 1460 documents

# %% [markdown]
# # Xây dựng StopWord

# %%
def build_stopWords(method='frequency', corpus=None, top_percent=0.05, min_freq=None):
    """
    Xây dựng danh sách stopwords
    
    Args:
        method: 'predefined' (dùng list có sẵn) hoặc 'frequency' (dựa trên tần suất)
        corpus: Danh sách văn bản để phân tích tần suất
        top_percent: % từ phổ biến nhất cần loại bỏ (mặc định 5%)
        min_freq: Ngưỡng tần suất tối thiểu (tùy chọn)
    
    Returns:
        Set các stopwords
    """
    
    if method == 'predefined':
        # Danh sách stopwords tiếng Anh cơ bản
        stopwords = {
            'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by', 'for', 'from',
            'has', 'he', 'in', 'is', 'it', 'its', 'of', 'on', 'that', 'the',
            'to', 'was', 'will', 'with', 'the', 'this', 'but', 'they', 'have',
            'had', 'what', 'when', 'where', 'who', 'which', 'why', 'how',
            'all', 'each', 'every', 'both', 'few', 'more', 'most', 'other',
            'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
            'than', 'too', 'very', 'can', 'will', 'just', 'should', 'now'
        }
        return stopwords
    
    elif method == 'frequency':
        if corpus is None:
            raise ValueError("Corpus không được để trống khi dùng method='frequency'")
        
        # Đếm tần suất xuất hiện của từng từ
        word_freq = {}
        total_words = 0
        
        for doc in corpus:
            words = doc.lower().split()
            for word in words:
                word_freq[word] = word_freq.get(word, 0) + 1
                total_words += 1
        
        # Sắp xếp theo tần suất giảm dần
        sorted_words = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)
        
        # Lấy top % từ phổ biến nhất
        num_stopwords = int(len(sorted_words) * top_percent)
        stopwords = set([word for word, freq in sorted_words[:num_stopwords]])
        
        # Nếu có min_freq, thêm điều kiện lọc
        if min_freq:
            stopwords = {word for word, freq in sorted_words 
                        if freq >= min_freq and word in stopwords}
        
        return stopwords
    
    elif method == 'combined':
        # Kết hợp cả hai: bắt đầu với predefined, bổ sung từ frequency
        stopwords = build_stopWords(method='predefined')
        
        if corpus:
            freq_stopwords = build_stopWords(method='frequency', corpus=corpus, 
                                            top_percent=top_percent, min_freq=min_freq)
            stopwords = stopwords.union(freq_stopwords)
        
        return stopwords
    
    else:
        raise ValueError("Method phải là 'predefined', 'frequency', hoặc 'combined'")
    

# Kiểm tra với None stopWords trước
stop_words = []

# %% [markdown]
# # Hàm xử lí từ và xây dựng hệ thống BoW

# %%
def build_vocab(corpus, stop_words):
    """
    Xây dựng hệ thống từ điển từ corpus, loại bỏ stop words.
    """
    
    word_list = []
    for sentence in corpus:
        words = sentence.lower().split()
        words = [w for w in words if w not in stop_words]
        word_list += words

    dictionary = sorted(set(word_list))
    return dictionary

def vectorize_sentence(text, dictionary, stop_words):
    """
    Biểu diễn câu dưới dạng vector (Bag of Words).
    ⚡ TỐI ƯU: Dùng dict đếm từ thay vì list.count() để tăng tốc độ
    """
    words = text.lower().split()
    words = [w for w in words if w not in stop_words]
    
    # Tạo dict đếm từ (thay vì dùng list.count() chậm)
    word_count = {}
    for word in words:
        word_count[word] = word_count.get(word, 0) + 1
    
    # Tạo vector dựa trên dictionary
    vector = np.zeros(len(dictionary), dtype=int)
    for i, word in enumerate(dictionary):
        vector[i] = word_count.get(word, 0)  # Lấy count, mặc định 0 nếu không có
    
    return vector

def corpus_to_matrix(corpus, dictionary, stop_words):
    """
    Chuyển toàn bộ corpus thành ma trận BoW
    """
    matrix = []
    for doc in corpus:
        vector = vectorize_sentence(doc, dictionary, stop_words)
        matrix.append(vector)
    
    return np.array(matrix)

# %% [markdown]
# # Các hàm tính khoảng cách

# %%
def euclidean_distance(a, b):
    """
    Tính khoảng cách Euclid
    """
    return np.sqrt(np.sum((np.array(a) - np.array(b)) ** 2))

def cosine_distance(a, b):
    """
    Tính khoảng cách Cosine
    """
    dot_product = np.dot(a, b)
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    
    # Tránh chia cho 0
    if norm_a == 0 or norm_b == 0:
        return 1.0
    
    return 1 - dot_product / (norm_a * norm_b)

def manhattan_distance(a, b):
    """
    Tính khoảng cách Manhattan
    """
    return np.sum(np.abs(np.array(a) - np.array(b)))

# %% [markdown]
# # Hàm truy vấn top-N văn bản giống test_doc nhất

# %%
def retrieve_documents(corpus, test_doc, n, stop_words, method='cosine', 
                       dictionary=None, corpus_matrix=None):
    """
    Truy vấn top-N văn bản giống test_doc nhất
    
    Args:
        corpus: Tập văn bản
        test_doc: Văn bản cần tìm kiếm
        n: Số lượng văn bản trả về
        stop_words: Danh sách stop words
        method: 'cosine', 'euclidean', hoặc 'manhattan'
        dictionary: (Optional) Từ điển đã build sẵn để tăng tốc
        corpus_matrix: (Optional) Ma trận corpus đã convert sẵn để tăng tốc
    
    Returns:
        List các tuple (index, distance, document)
    """
    # ⚡ TỐI ƯU: Dùng dictionary & corpus_matrix có sẵn thay vì build lại
    if dictionary is None:
        dictionary = build_vocab(corpus, stop_words)
    
    if corpus_matrix is None:
        corpus_matrix = corpus_to_matrix(corpus, dictionary, stop_words)
    
    # Chuyển test_doc thành vector
    test_vector = vectorize_sentence(test_doc, dictionary, stop_words)
    
    # Tính khoảng cách
    distances = []
    for i, doc_vector in enumerate(corpus_matrix):
        if method == 'cosine':
            dist = cosine_distance(test_vector, doc_vector)
        elif method == 'euclidean':
            dist = euclidean_distance(test_vector, doc_vector)
        elif method == 'manhattan':
            dist = manhattan_distance(test_vector, doc_vector)
        else:
            raise ValueError("Method phải là 'cosine', 'euclidean', hoặc 'manhattan'")
        
        distances.append((i, dist, corpus[i]))
    
    # Sắp xếp theo khoảng cách (tăng dần)
    distances.sort(key=lambda x: x[1])
    
    # Trả về top-N
    return distances[:n]

# %% [markdown]
# # DEMO

# %%
#print("\nCorpus:")
#for i, doc in enumerate(corpus[:3]):
#    print(f"  [{i}] {doc[:100]}...")

# Văn bản test
corpus_ids, corpus_texts = extract_W_sections('data.txt')  # Lấy tất cả
corpus = corpus_texts  # Chỉ lấy phần văn bản
print(f"✓ Số lượng văn bản (all): {len(corpus)} documents")
print(f"  - IDs: {len(corpus_ids)}")
print(f"  - Texts: {len(corpus_texts)}")

# ⚡ TỐI ƯU: Xây dựng từ điển và corpus matrix MỘT LẦN
print(f"\n⚡ Pre-computing dictionary và corpus matrix...")
dictionary = build_vocab(corpus, stop_words)
corpus_matrix = corpus_to_matrix(corpus, dictionary, stop_words)
print(f"✓ Dictionary: {len(dictionary)} từ")
print(f"✓ Corpus matrix: {corpus_matrix.shape}")

n = 1  # Số lượng văn bản cần trả về
# Out:
# ✓ Số lượng văn bản (all): 1460 documents
#   - IDs: 1460
#   - Texts: 1460
#
# ⚡ Pre-computing dictionary và corpus matrix...
# ✓ Dictionary: 17441 từ
# ✓ Corpus matrix: (1460, 17441)

# %% [markdown]
# # Truy Vấn

# %%
print("KẾT QUẢ TRUY VẤN")

# Lấy ID và văn bản từ query
query_ids, query_texts = extract_W_sections('querry.txt')

# Truy vấn với 3 phương pháp
cosine_results = {}
euclidean_results = {}
manhattan_results = {}

# ⚡ Truy vấn với Cosine Distance (dùng corpus_matrix có sẵn)
print(f"\nTop-{n} văn bản (Cosine Distance):")
for query_id, query_text in zip(query_ids, query_texts):
    results = retrieve_documents(corpus, query_text, n, stop_words, method='cosine',
                                 dictionary=dictionary, corpus_matrix=corpus_matrix)
    cosine_results[query_id] = results[0][0]  # Lưu ID của document trả về
    
    for rank, (idx, dist, doc) in enumerate(results, 1):
        print(f"  Query {query_id} - {rank}. Doc[{idx}] Distance: {dist:.4f}")

# ⚡ Truy vấn với Euclidean Distance (dùng corpus_matrix có sẵn)
print(f"\nTop-{n} văn bản (Euclidean Distance):")
for query_id, query_text in zip(query_ids, query_texts):
    results = retrieve_documents(corpus, query_text, n, stop_words, method='euclidean',
                                 dictionary=dictionary, corpus_matrix=corpus_matrix)
    euclidean_results[query_id] = results[0][0]
    
    for rank, (idx, dist, doc) in enumerate(results, 1):
        print(f"  Query {query_id} - {rank}. Doc[{idx}] Distance: {dist:.4f}")

# ⚡ Truy vấn với Manhattan Distance (dùng corpus_matrix có sẵn)
print(f"\nTop-{n} văn bản (Manhattan Distance):")
for query_id, query_text in zip(query_ids, query_texts):
    results = retrieve_documents(corpus, query_text, n, stop_words, method='manhattan',
                                 dictionary=dictionary, corpus_matrix=corpus_matrix)
    manhattan_results[query_id] = results[0][0]
    
    for rank, (idx, dist, doc) in enumerate(results, 1):
        print(f"  Query {query_id} - {rank}. Doc[{idx}] Distance: {dist:.4f}")
# Out:
# KẾT QUẢ TRUY VẤN
#
# Top-1 văn bản (Cosine Distance):
#   Query 1 - 1. Doc[16] Distance: 0.4495
#   Query 2 - 1. Doc[1265] Distance: 0.6237
#   Query 3 - 1. Doc[1165] Distance: 0.7348
#   Query 4 - 1. Doc[1189] Distance: 0.6488
#   Query 5 - 1. Doc[374] Distance: 0.5671
#   Query 6 - 1. Doc[626] Distance: 0.6003
#   Query 7 - 1. Doc[923] Distance: 0.4849
#   Query 8 - 1. Doc[132] Distance: 0.5082
#   Query 9 - 1. Doc[1111] Distance: 0.5127
#   Query 10 - 1. Doc[1] Distance: 0.5122
#   Query 11 - 1. Doc[534] Distance: 0.4443
#   Query 12 - 1. Doc[1189] Distance: 0.5273
#   Query 13 - 1. Doc[146] Distance: 0.4756
#   Query 14 - 1. Doc[1143] Distance: 0.7275
#   Query 15 - 1. Doc[663] Distance: 0.4805
#   Query 16 - 1. Doc[59] Distance: 0.4488
#   Query 17 - 1. Doc[1157] Distance: 0.6628
#   Query 18 - 1. Doc[807] Distance: 0.6100
#   Query 19 - 1. Doc[816] Distance: 0.5944
#   Query 20 - 1. Doc[1165] Distance: 0.7500
#   Query 21 - 1. Doc[647] Distance: 0.4334
#   Query 22 - 1. Doc[132] Distance: 0.5138
#   Query 23 - 1. Doc[201] Distance: 0.4962
#   Query 24 - 1. Doc[534] Distance: 0.5020
#   Query 25 - 1. Doc[528] Distance: 0.5517
#   Query 26 - 1. Doc[1346] Distance: 0.5246
#   Query 27 - 1. Doc[564] Distance: 0.7515
#   Query 28 - 1. Doc[1006] Distance: 0.6062
#   Query 29 - 1. Doc[672] Distance: 0.6574
#   Query 30 - 1. Doc[374] Distance: 0.6033
#   Query 31 - 1. Doc[489] Distance: 0.5225
#   Query 32 - 1. Doc[374] Distance: 0.5226
#   Query 33 - 1. Doc[629] Distance: 0.3601
#   Query 34 - 1. Doc[203] Distance: 0.6236
#   Query 35 - 1. Doc[174] Distance: 0.6389
#   Query 36 - 1. Doc[818] Distance: 0.3867
#   Query 37 - 1. Doc[637] Distance: 0.5109
#   Query 38 - 1. Doc[496] Distance: 0.4594
#   Query 39 - 1. Doc[1357] Distance: 0.2346
#   Query 40 - 1. Doc[341] Distance: 0.3229
#   Query 41 - 1. Doc[444] Distance: 0.4050
#   Query 42 - 1. Doc[1226] Distance: 0.3455
#   Query 43 - 1. Doc[15] Distance: 0.2442
#   Query 44 - 1. Doc[16] Distance: 0.4931
#   Query 45 - 1. Doc[122] Distance: 0.3432
#   Query 46 - 1. Doc[1051] Distance: 0.3312
#   Query 47 - 1. Doc[1261] Distance: 0.4379
#   Query 48 - 1. Doc[654] Distance: 0.4970
#   Query 49 - 1. Doc[146] Distance: 0.3635
#   Query 50 - 1. Doc[387] Distance: 0.5432
#   Query 51 - 1. Doc[1174] Distance: 0.5400
#   Query 52 - 1. Doc[381] Distance: 0.3343
#   Query 53 - 1. Doc[16] Distance: 0.3544
#   Query 54 - 1. Doc[1456] Distance: 0.2571
#   Query 55 - 1. Doc[381] Distance: 0.3720
#   Query 56 - 1. Doc[647] Distance: 0.3418
#   Query 57 - 1. Doc[1065] Distance: 0.4798
#   Query 58 - 1. Doc[16] Distance: 0.3102
#   Query 59 - 1. Doc[356] Distance: 0.2812
#   Query 60 - 1. Doc[1417] Distance: 0.2781
#   Query 61 - 1. Doc[663] Distance: 0.4065
#   Query 62 - 1. Doc[640] Distance: 0.2099
#   Query 63 - 1. Doc[1414] Distance: 0.3684
#   Query 64 - 1. Doc[95] Distance: 0.4628
#   Query 65 - 1. Doc[643] Distance: 0.3084
#   Query 66 - 1. Doc[347] Distance: 0.4711
#   Query 67 - 1. Doc[1123] Distance: 0.2006
#   Query 68 - 1. Doc[1406] Distance: 0.2217
#   Query 69 - 1. Doc[797] Distance: 0.2356
#   Query 70 - 1. Doc[1357] Distance: 0.2678
#   Query 71 - 1. Doc[1416] Distance: 0.1713
#   Query 72 - 1. Doc[635] Distance: 0.3964
#   Query 73 - 1. Doc[678] Distance: 0.2911
#   Query 74 - 1. Doc[210] Distance: 0.2008
#   Query 75 - 1. Doc[403] Distance: 0.3204
#   Query 76 - 1. Doc[15] Distance: 0.2209
#   Query 77 - 1. Doc[1123] Distance: 0.2608
#   Query 78 - 1. Doc[1345] Distance: 0.1981
#   Query 79 - 1. Doc[797] Distance: 0.3008
#   Query 80 - 1. Doc[640] Distance: 0.1607
#   Query 81 - 1. Doc[629] Distance: 0.2679
#   Query 82 - 1. Doc[1119] Distance: 0.3398
#   Query 83 - 1. Doc[1123] Distance: 0.3137
#   Query 84 - 1. Doc[648] Distance: 0.2857
#   Query 85 - 1. Doc[797] Distance: 0.1707
#   Query 86 - 1. Doc[380] Distance: 0.4243
#   Query 87 - 1. Doc[1416] Distance: 0.2367
#   Query 88 - 1. Doc[640] Distance: 0.3653
#   Query 89 - 1. Doc[1406] Distance: 0.3059
#   Query 90 - 1. Doc[640] Distance: 0.1927
#   Query 91 - 1. Doc[1019] Distance: 0.2859
#   Query 92 - 1. Doc[1456] Distance: 0.3982
#   Query 93 - 1. Doc[1123] Distance: 0.2167
#   Query 94 - 1. Doc[1135] Distance: 0.2232
#   Query 95 - 1. Doc[318] Distance: 0.3641
#   Query 96 - 1. Doc[643] Distance: 0.3712
#   Query 97 - 1. Doc[264] Distance: 0.3047
#   Query 98 - 1. Doc[1123] Distance: 0.2805
#   Query 99 - 1. Doc[594] Distance: 0.3439
#   Query 100 - 1. Doc[1119] Distance: 0.3377
#   Query 101 - 1. Doc[460] Distance: 0.4240
#   Query 102 - 1. Doc[1416] Distance: 0.2442
#   Query 103 - 1. Doc[418] Distance: 0.2755
#   Query 104 - 1. Doc[893] Distance: 0.2601
#   Query 105 - 1. Doc[80] Distance: 0.3882
#   Query 106 - 1. Doc[1406] Distance: 0.2614
#   Query 107 - 1. Doc[1406] Distance: 0.1643
#   Query 108 - 1. Doc[1417] Distance: 0.3765
#   Query 109 - 1. Doc[1339] Distance: 0.1977
#   Query 110 - 1. Doc[797] Distance: 0.2388
#   Query 111 - 1. Doc[1406] Distance: 0.2282
#   Query 112 - 1. Doc[1416] Distance: 0.2054
#
# Top-1 văn bản (Euclidean Distance):
#   Query 1 - 1. Doc[1287] Distance: 6.7823
#   Query 2 - 1. Doc[1294] Distance: 5.2915
#   Query 3 - 1. Doc[1099] Distance: 4.1231
#   Query 4 - 1. Doc[1287] Distance: 4.3589
#   Query 5 - 1. Doc[1165] Distance: 5.2915
#   Query 6 - 1. Doc[1295] Distance: 4.4721
#   Query 7 - 1. Doc[1282] Distance: 6.1644
#   Query 8 - 1. Doc[1288] Distance: 4.8990
#   Query 9 - 1. Doc[1165] Distance: 4.6904
#   Query 10 - 1. Doc[1287] Distance: 3.8730
#   Query 11 - 1. Doc[1099] Distance: 3.7417
#   Query 12 - 1. Doc[1099] Distance: 4.0000
#   Query 13 - 1. Doc[1283] Distance: 4.2426
#   Query 14 - 1. Doc[1283] Distance: 3.7417
#   Query 15 - 1. Doc[1085] Distance: 5.5678
#   Query 16 - 1. Doc[1287] Distance: 5.0990
#   Query 17 - 1. Doc[1287] Distance: 4.1231
#   Query 18 - 1. Doc[1295] Distance: 5.1962
#   Query 19 - 1. Doc[1279] Distance: 4.5826
#   Query 20 - 1. Doc[1295] Distance: 3.6056
#   Query 21 - 1. Doc[1295] Distance: 3.7417
#   Query 22 - 1. Doc[1295] Distance: 3.6056
#   Query 23 - 1. Doc[1287] Distance: 4.3589
#   Query 24 - 1. Doc[1165] Distance: 5.4772
#   Query 25 - 1. Doc[1282] Distance: 3.4641
#   Query 26 - 1. Doc[1287] Distance: 4.1231
#   Query 27 - 1. Doc[1295] Distance: 4.4721
#   Query 28 - 1. Doc[1295] Distance: 4.1231
#   Query 29 - 1. Doc[1287] Distance: 3.4641
#   Query 30 - 1. Doc[1300] Distance: 3.7417
#   Query 31 - 1. Doc[1295] Distance: 3.6056
#   Query 32 - 1. Doc[1282] Distance: 5.4772
#   Query 33 - 1. Doc[930] Distance: 4.3589
#   Query 34 - 1. Doc[1287] Distance: 3.7417
#   Query 35 - 1. Doc[1099] Distance: 4.2426
#   Query 36 - 1. Doc[1132] Distance: 7.5498
#   Query 37 - 1. Doc[709] Distance: 10.0995
#   Query 38 - 1. Doc[1293] Distance: 8.3066
#   Query 39 - 1. Doc[1318] Distance: 9.8995
#   Query 40 - 1. Doc[53] Distance: 8.3666
#   Query 41 - 1. Doc[968] Distance: 9.1652
#   Query 42 - 1. Doc[53] Distance: 7.6811
#   Query 43 - 1. Doc[1106] Distance: 9.0554
#   Query 44 - 1. Doc[1082] Distance: 8.5440
#   Query 45 - 1. Doc[371] Distance: 10.1489
#   Query 46 - 1. Doc[717] Distance: 11.4455
#   Query 47 - 1. Doc[709] Distance: 10.1980
#   Query 48 - 1. Doc[1165] Distance: 11.6619
#   Query 49 - 1. Doc[1259] Distance: 12.0830
#   Query 50 - 1. Doc[1082] Distance: 10.9087
#   Query 51 - 1. Doc[68] Distance: 6.4031
#   Query 52 - 1. Doc[288] Distance: 8.5440
#   Query 53 - 1. Doc[35] Distance: 10.2956
#   Query 54 - 1. Doc[786] Distance: 7.9373
#   Query 55 - 1. Doc[1132] Distance: 6.4031
#   Query 56 - 1. Doc[930] Distance: 7.6158
#   Query 57 - 1. Doc[1293] Distance: 9.3274
#   Query 58 - 1. Doc[986] Distance: 11.2694
#   Query 59 - 1. Doc[113] Distance: 13.0384
#   Query 60 - 1. Doc[49] Distance: 14.0357
#   Query 61 - 1. Doc[443] Distance: 10.6301
#   Query 62 - 1. Doc[869] Distance: 12.3288
#   Query 63 - 1. Doc[782] Distance: 13.4536
#   Query 64 - 1. Doc[1288] Distance: 9.0000
#   Query 65 - 1. Doc[50] Distance: 12.4900
#   Query 66 - 1. Doc[930] Distance: 9.1104
#   Query 67 - 1. Doc[378] Distance: 20.4939
#   Query 68 - 1. Doc[359] Distance: 13.9284
#   Query 69 - 1. Doc[1011] Distance: 13.3041
#   Query 70 - 1. Doc[1240] Distance: 18.3848
#   Query 71 - 1. Doc[952] Distance: 15.5885
#   Query 72 - 1. Doc[1125] Distance: 14.5602
#   Query 73 - 1. Doc[678] Distance: 12.7279
#   Query 74 - 1. Doc[210] Distance: 10.5357
#   Query 75 - 1. Doc[1315] Distance: 10.2956
#   Query 76 - 1. Doc[401] Distance: 10.4403
#   Query 77 - 1. Doc[1206] Distance: 13.2288
#   Query 78 - 1. Doc[38] Distance: 10.9087
#   Query 79 - 1. Doc[287] Distance: 10.6771
#   Query 80 - 1. Doc[640] Distance: 17.1464
#   Query 81 - 1. Doc[573] Distance: 14.6287
#   Query 82 - 1. Doc[531] Distance: 13.8203
#   Query 83 - 1. Doc[287] Distance: 13.1909
#   Query 84 - 1. Doc[828] Distance: 11.4018
#   Query 85 - 1. Doc[797] Distance: 19.0000
#   Query 86 - 1. Doc[782] Distance: 12.8841
#   Query 87 - 1. Doc[210] Distance: 15.0000
#   Query 88 - 1. Doc[1224] Distance: 9.1104
#   Query 89 - 1. Doc[986] Distance: 12.0000
#   Query 90 - 1. Doc[640] Distance: 25.0400
#   Query 91 - 1. Doc[798] Distance: 18.9473
#   Query 92 - 1. Doc[90] Distance: 8.8882
#   Query 93 - 1. Doc[226] Distance: 16.2481
#   Query 94 - 1. Doc[72] Distance: 10.9545
#   Query 95 - 1. Doc[443] Distance: 12.5698
#   Query 96 - 1. Doc[968] Distance: 8.8318
#   Query 97 - 1. Doc[432] Distance: 15.0665
#   Query 98 - 1. Doc[113] Distance: 14.8324
#   Query 99 - 1. Doc[72] Distance: 12.8841
#   Query 100 - 1. Doc[288] Distance: 9.5917
#   Query 101 - 1. Doc[1120] Distance: 12.3693
#   Query 102 - 1. Doc[997] Distance: 16.8819
#   Query 103 - 1. Doc[1224] Distance: 7.8102
#   Query 104 - 1. Doc[148] Distance: 11.8322
#   Query 105 - 1. Doc[443] Distance: 9.2736
#   Query 106 - 1. Doc[113] Distance: 16.4621
#   Query 107 - 1. Doc[798] Distance: 13.3791
#   Query 108 - 1. Doc[1259] Distance: 11.3137
#   Query 109 - 1. Doc[997] Distance: 18.5203
#   Query 110 - 1. Doc[132] Distance: 14.5258
#   Query 111 - 1. Doc[401] Distance: 11.4018
#   Query 112 - 1. Doc[823] Distance: 9.2736
#
# Top-1 văn bản (Manhattan Distance):
#   Query 1 - 1. Doc[1287] Distance: 34.0000
#   Query 2 - 1. Doc[1288] Distance: 27.0000
#   Query 3 - 1. Doc[1287] Distance: 16.0000
#   Query 4 - 1. Doc[1287] Distance: 19.0000
#   Query 5 - 1. Doc[1165] Distance: 26.0000
#   Query 6 - 1. Doc[1295] Distance: 18.0000
#   Query 7 - 1. Doc[1295] Distance: 33.0000
#   Query 8 - 1. Doc[1288] Distance: 22.0000
#   Query 9 - 1. Doc[1165] Distance: 22.0000
#   Query 10 - 1. Doc[1287] Distance: 15.0000
#   Query 11 - 1. Doc[1099] Distance: 14.0000
#   Query 12 - 1. Doc[1099] Distance: 16.0000
#   Query 13 - 1. Doc[1283] Distance: 18.0000
#   Query 14 - 1. Doc[1283] Distance: 14.0000
#   Query 15 - 1. Doc[1085] Distance: 27.0000
#   Query 16 - 1. Doc[1287] Distance: 22.0000
#   Query 17 - 1. Doc[1287] Distance: 17.0000
#   Query 18 - 1. Doc[1295] Distance: 25.0000
#   Query 19 - 1. Doc[1287] Distance: 18.0000
#   Query 20 - 1. Doc[1287] Distance: 12.0000
#   Query 21 - 1. Doc[1295] Distance: 14.0000
#   Query 22 - 1. Doc[1287] Distance: 12.0000
#   Query 23 - 1. Doc[1287] Distance: 19.0000
#   Query 24 - 1. Doc[1165] Distance: 24.0000
#   Query 25 - 1. Doc[1282] Distance: 12.0000
#   Query 26 - 1. Doc[1287] Distance: 15.0000
#   Query 27 - 1. Doc[1287] Distance: 15.0000
#   Query 28 - 1. Doc[1287] Distance: 16.0000
#   Query 29 - 1. Doc[1287] Distance: 12.0000
#   Query 30 - 1. Doc[1287] Distance: 14.0000
#   Query 31 - 1. Doc[1287] Distance: 12.0000
#   Query 32 - 1. Doc[1282] Distance: 26.0000
#   Query 33 - 1. Doc[930] Distance: 19.0000
#   Query 34 - 1. Doc[1287] Distance: 14.0000
#   Query 35 - 1. Doc[1287] Distance: 17.0000
#   Query 36 - 1. Doc[1287] Distance: 39.0000
#   Query 37 - 1. Doc[1295] Distance: 61.0000
#   Query 38 - 1. Doc[1288] Distance: 58.0000
#   Query 39 - 1. Doc[1165] Distance: 69.0000
#   Query 40 - 1. Doc[709] Distance: 51.0000
#   Query 41 - 1. Doc[1311] Distance: 58.0000
#   Query 42 - 1. Doc[1165] Distance: 48.0000
#   Query 43 - 1. Doc[1099] Distance: 62.0000
#   Query 44 - 1. Doc[1082] Distance: 57.0000
#   Query 45 - 1. Doc[1288] Distance: 59.0000
#   Query 46 - 1. Doc[1288] Distance: 85.0000
#   Query 47 - 1. Doc[1302] Distance: 70.0000
#   Query 48 - 1. Doc[1288] Distance: 87.0000
#   Query 49 - 1. Doc[1295] Distance: 77.0000
#   Query 50 - 1. Doc[1099] Distance: 72.0000
#   Query 51 - 1. Doc[1287] Distance: 30.0000
#   Query 52 - 1. Doc[967] Distance: 54.0000
#   Query 53 - 1. Doc[709] Distance: 61.0000
#   Query 54 - 1. Doc[1287] Distance: 50.0000
#   Query 55 - 1. Doc[1287] Distance: 31.0000
#   Query 56 - 1. Doc[1099] Distance: 43.0000
#   Query 57 - 1. Doc[1099] Distance: 62.0000
#   Query 58 - 1. Doc[1302] Distance: 91.0000
#   Query 59 - 1. Doc[443] Distance: 128.0000
#   Query 60 - 1. Doc[930] Distance: 124.0000
#   Query 61 - 1. Doc[1289] Distance: 75.0000
#   Query 62 - 1. Doc[1132] Distance: 92.0000
#   Query 63 - 1. Doc[1412] Distance: 121.0000
#   Query 64 - 1. Doc[1288] Distance: 61.0000
#   Query 65 - 1. Doc[443] Distance: 112.0000
#   Query 66 - 1. Doc[1287] Distance: 61.0000
#   Query 67 - 1. Doc[68] Distance: 194.0000
#   Query 68 - 1. Doc[1259] Distance: 125.0000
#   Query 69 - 1. Doc[1137] Distance: 121.0000
#   Query 70 - 1. Doc[534] Distance: 192.0000
#   Query 71 - 1. Doc[1099] Distance: 148.0000
#   Query 72 - 1. Doc[1283] Distance: 109.0000
#   Query 73 - 1. Doc[968] Distance: 109.0000
#   Query 74 - 1. Doc[1099] Distance: 86.0000
#   Query 75 - 1. Doc[1287] Distance: 77.0000
#   Query 76 - 1. Doc[968] Distance: 80.0000
#   Query 77 - 1. Doc[968] Distance: 99.0000
#   Query 78 - 1. Doc[1287] Distance: 83.0000
#   Query 79 - 1. Doc[1132] Distance: 76.0000
#   Query 80 - 1. Doc[604] Distance: 157.0000
#   Query 81 - 1. Doc[573] Distance: 120.0000
#   Query 82 - 1. Doc[968] Distance: 92.0000
#   Query 83 - 1. Doc[1224] Distance: 111.0000
#   Query 84 - 1. Doc[1126] Distance: 95.0000
#   Query 85 - 1. Doc[968] Distance: 191.0000
#   Query 86 - 1. Doc[968] Distance: 107.0000
#   Query 87 - 1. Doc[68] Distance: 122.0000
#   Query 88 - 1. Doc[53] Distance: 67.0000
#   Query 89 - 1. Doc[968] Distance: 93.0000
#   Query 90 - 1. Doc[780] Distance: 302.0000
#   Query 91 - 1. Doc[35] Distance: 183.0000
#   Query 92 - 1. Doc[1287] Distance: 53.0000
#   Query 93 - 1. Doc[35] Distance: 155.0000
#   Query 94 - 1. Doc[68] Distance: 80.0000
#   Query 95 - 1. Doc[35] Distance: 101.0000
#   Query 96 - 1. Doc[968] Distance: 60.0000
#   Query 97 - 1. Doc[968] Distance: 137.0000
#   Query 98 - 1. Doc[1295] Distance: 125.0000
#   Query 99 - 1. Doc[968] Distance: 122.0000
#   Query 100 - 1. Doc[1311] Distance: 62.0000
#   Query 101 - 1. Doc[1132] Distance: 90.0000
#   Query 102 - 1. Doc[823] Distance: 138.0000
#   Query 103 - 1. Doc[1003] Distance: 50.0000
#   Query 104 - 1. Doc[1293] Distance: 88.0000
#   Query 105 - 1. Doc[443] Distance: 66.0000
#   Query 106 - 1. Doc[573] Distance: 164.0000
#   Query 107 - 1. Doc[68] Distance: 117.0000
#   Query 108 - 1. Doc[1302] Distance: 88.0000
#   Query 109 - 1. Doc[573] Distance: 182.0000
#   Query 110 - 1. Doc[1132] Distance: 121.0000
#   Query 111 - 1. Doc[68] Distance: 81.0000
#   Query 112 - 1. Doc[68] Distance: 60.0000

# %% [markdown]
# # Hàm so sánh độ chính xác với thực tế

# %%
def extract_results():
    """
    Đọc file result.txt và trích xuất query ID và relevant doc IDs
    Returns:
        Dictionary: {query_id: [list of relevant doc ids]}
    """
    relevant_docs = {}
    with open('result.txt', 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                parts = line.split()
                if len(parts) >= 2:
                    query_id = parts[0]
                    doc_id = parts[1]
                    
                    if query_id not in relevant_docs:
                        relevant_docs[query_id] = []
                    relevant_docs[query_id].append(doc_id)
    
    return relevant_docs

def compare_methods(cosine_results=cosine_results, euclidean_results=euclidean_results, manhattan_results=manhattan_results):
    """
    So sánh kết quả từ 3 phương pháp với ground truth
    Trả về accuracy (%)
    """
    # Lấy ground truth từ result.txt
    relevant_docs = extract_results()
    
    # Tính accuracy cho từng phương pháp
    methods = {
        'cosine': cosine_results,
        'euclidean': euclidean_results,
        'manhattan': manhattan_results
    }
    
    results = {}
    
    for method_name, method_results in methods.items():
        hits = 0
        total = 0
        
        for query_id, retrieved_doc_id in method_results.items():
            total += 1
            # Kiểm tra xem retrieved_doc_id có trong danh sách relevant docs không
            if query_id in relevant_docs:
                if str(retrieved_doc_id) in relevant_docs[query_id]:
                    hits += 1
        
        # Tính tỉ lệ %
        accuracy = (hits / total * 100) if total > 0 else 0
        results[method_name] = {
            'hits': hits,
            'total': total,
            'accuracy': accuracy
        }
        
        print(f"\n{method_name.upper()}:")
        print(f"  Hits: {hits}/{total}")
        print(f"  Accuracy: {accuracy:.2f}%")
    
    return results

# Gọi hàm so sánh
compare_results = compare_methods(cosine_results, euclidean_results, manhattan_results)
# Out:
# COSINE:
#   Hits: 4/112
#   Accuracy: 3.57%
#
# EUCLIDEAN:
#   Hits: 3/112
#   Accuracy: 2.68%
#
# MANHATTAN:
#   Hits: 3/112
#   Accuracy: 2.68%

# %% [markdown]
# # Truy vấn lại với StopWords

# %%
stop_words = list(build_stopWords(method='combined', corpus=corpus_texts, top_percent=0.05))

print("KẾT QUẢ TRUY VẤN CÓ STOP WORDS")

# Lấy ID và văn bản từ query
query_ids, query_texts = extract_W_sections('querry.txt')

# Truy vấn với 3 phương pháp
cosine_results_with_stopwords = {}
euclidean_results_with_stopwords = {}
manhattan_results_with_stopwords = {}

# Truy vấn với Cosine Distance
print(f"\nTop-{n} văn bản (Cosine Distance):")
for query_id, query_text in zip(query_ids, query_texts):
    results = retrieve_documents(corpus, query_text, n, stop_words, method='cosine')
    cosine_results_with_stopwords[query_id] = results[0][0]  # Lưu ID của document trả về
    
    for rank, (idx, dist, doc) in enumerate(results, 1):
        print(f"  Query {query_id} - {rank}. Doc[{idx}] Distance: {dist:.4f}")

# Truy vấn với Euclidean Distance
print(f"\nTop-{n} văn bản (Euclidean Distance):")
for query_id, query_text in zip(query_ids, query_texts):
    results = retrieve_documents(corpus, query_text, n, stop_words, method='euclidean')
    euclidean_results_with_stopwords[query_id] = results[0][0]
    
    for rank, (idx, dist, doc) in enumerate(results, 1):
        print(f"  Query {query_id} - {rank}. Doc[{idx}] Distance: {dist:.4f}")

# Truy vấn với Manhattan Distance
print(f"\nTop-{n} văn bản (Manhattan Distance):")
for query_id, query_text in zip(query_ids, query_texts):
    results = retrieve_documents(corpus, query_text, n, stop_words, method='manhattan')
    manhattan_results_with_stopwords[query_id] = results[0][0]
    
    for rank, (idx, dist, doc) in enumerate(results, 1):
        print(f"  Query {query_id} - {rank}. Doc[{idx}] Distance: {dist:.4f}")
# Out:
# KẾT QUẢ TRUY VẤN CÓ STOP WORDS
#
# Top-1 văn bản (Cosine Distance):
#   Query 1 - 1. Doc[466] Distance: 0.8586
#   Query 2 - 1. Doc[596] Distance: 0.8639
#   Query 3 - 1. Doc[468] Distance: 0.7278
#   Query 4 - 1. Doc[35] Distance: 0.7818
#   Query 5 - 1. Doc[861] Distance: 0.7675
#   Query 6 - 1. Doc[1132] Distance: 0.7418
#   Query 7 - 1. Doc[151] Distance: 0.9000
#   Query 8 - 1. Doc[538] Distance: 0.6220
#   Query 9 - 1. Doc[1132] Distance: 0.7764
#   Query 10 - 1. Doc[564] Distance: 0.6362
#   Query 11 - 1. Doc[133] Distance: 0.6797
#   Query 12 - 1. Doc[1209] Distance: 0.7990
#   Query 13 - 1. Doc[363] Distance: 0.8492
#   Query 14 - 1. Doc[0] Distance: 1.0000
#   Query 15 - 1. Doc[655] Distance: 0.7396
#   Query 16 - 1. Doc[733] Distance: 0.8399
#   Query 17 - 1. Doc[36] Distance: 0.8709
#   Query 18 - 1. Doc[265] Distance: 0.8207
#   Query 19 - 1. Doc[178] Distance: 0.6307
#   Query 20 - 1. Doc[133] Distance: 0.5196
#   Query 21 - 1. Doc[1204] Distance: 0.6464
#   Query 22 - 1. Doc[914] Distance: 0.5528
#   Query 23 - 1. Doc[1145] Distance: 0.2670
#   Query 24 - 1. Doc[1274] Distance: 0.8218
#   Query 25 - 1. Doc[1288] Distance: 0.5528
#   Query 26 - 1. Doc[1099] Distance: 0.2929
#   Query 27 - 1. Doc[0] Distance: 1.0000
#   Query 28 - 1. Doc[1091] Distance: 0.7959
#   Query 29 - 1. Doc[752] Distance: 0.6464
#   Query 30 - 1. Doc[781] Distance: 0.6667
#   Query 31 - 1. Doc[534] Distance: 0.6985
#   Query 32 - 1. Doc[0] Distance: 1.0000
#   Query 33 - 1. Doc[1080] Distance: 0.4117
#   Query 34 - 1. Doc[1179] Distance: 0.4343
#   Query 35 - 1. Doc[1206] Distance: 0.8000
#   Query 36 - 1. Doc[68] Distance: 0.8174
#   Query 37 - 1. Doc[1447] Distance: 0.8583
#   Query 38 - 1. Doc[968] Distance: 0.8492
#   Query 39 - 1. Doc[461] Distance: 0.8449
#   Query 40 - 1. Doc[458] Distance: 0.8333
#   Query 41 - 1. Doc[1221] Distance: 0.7428
#   Query 42 - 1. Doc[846] Distance: 0.8075
#   Query 43 - 1. Doc[466] Distance: 0.8093
#   Query 44 - 1. Doc[370] Distance: 0.8500
#   Query 45 - 1. Doc[1294] Distance: 0.8174
#   Query 46 - 1. Doc[175] Distance: 0.8174
#   Query 47 - 1. Doc[1288] Distance: 0.8310
#   Query 48 - 1. Doc[1218] Distance: 0.8801
#   Query 49 - 1. Doc[544] Distance: 0.8259
#   Query 50 - 1. Doc[260] Distance: 0.7760
#   Query 51 - 1. Doc[1221] Distance: 0.7165
#   Query 52 - 1. Doc[483] Distance: 0.7745
#   Query 53 - 1. Doc[1232] Distance: 0.7713
#   Query 54 - 1. Doc[786] Distance: 0.8333
#   Query 55 - 1. Doc[264] Distance: 0.7072
#   Query 56 - 1. Doc[262] Distance: 0.8349
#   Query 57 - 1. Doc[1229] Distance: 0.7856
#   Query 58 - 1. Doc[222] Distance: 0.8665
#   Query 59 - 1. Doc[508] Distance: 0.8712
#   Query 60 - 1. Doc[1116] Distance: 0.7865
#   Query 61 - 1. Doc[522] Distance: 0.8733
#   Query 62 - 1. Doc[809] Distance: 0.6756
#   Query 63 - 1. Doc[622] Distance: 0.8372
#   Query 64 - 1. Doc[1243] Distance: 0.8925
#   Query 65 - 1. Doc[447] Distance: 0.6047
#   Query 66 - 1. Doc[1360] Distance: 0.8533
#   Query 67 - 1. Doc[829] Distance: 0.6330
#   Query 68 - 1. Doc[1116] Distance: 0.8543
#   Query 69 - 1. Doc[738] Distance: 0.8865
#   Query 70 - 1. Doc[1133] Distance: 0.8457
#   Query 71 - 1. Doc[1130] Distance: 0.5659
#   Query 72 - 1. Doc[807] Distance: 0.8686
#   Query 73 - 1. Doc[1117] Distance: 0.7441
#   Query 74 - 1. Doc[210] Distance: 0.8077
#   Query 75 - 1. Doc[398] Distance: 0.8842
#   Query 76 - 1. Doc[210] Distance: 0.8200
#   Query 77 - 1. Doc[1158] Distance: 0.9125
#   Query 78 - 1. Doc[463] Distance: 0.8807
#   Query 79 - 1. Doc[707] Distance: 0.7538
#   Query 80 - 1. Doc[54] Distance: 0.8259
#   Query 81 - 1. Doc[1322] Distance: 0.5894
#   Query 82 - 1. Doc[816] Distance: 0.7205
#   Query 83 - 1. Doc[833] Distance: 0.7567
#   Query 84 - 1. Doc[809] Distance: 0.7351
#   Query 85 - 1. Doc[990] Distance: 0.8941
#   Query 86 - 1. Doc[1116] Distance: 0.8149
#   Query 87 - 1. Doc[285] Distance: 0.8075
#   Query 88 - 1. Doc[1311] Distance: 0.8509
#   Query 89 - 1. Doc[144] Distance: 0.7524
#   Query 90 - 1. Doc[852] Distance: 0.8345
#   Query 91 - 1. Doc[46] Distance: 0.8657
#   Query 92 - 1. Doc[519] Distance: 0.7913
#   Query 93 - 1. Doc[484] Distance: 0.8411
#   Query 94 - 1. Doc[826] Distance: 0.8882
#   Query 95 - 1. Doc[530] Distance: 0.6595
#   Query 96 - 1. Doc[1284] Distance: 0.8333
#   Query 97 - 1. Doc[228] Distance: 0.8361
#   Query 98 - 1. Doc[625] Distance: 0.5969
#   Query 99 - 1. Doc[625] Distance: 0.8048
#   Query 100 - 1. Doc[375] Distance: 0.8137
#   Query 101 - 1. Doc[1088] Distance: 0.8116
#   Query 102 - 1. Doc[500] Distance: 0.7868
#   Query 103 - 1. Doc[871] Distance: 0.8279
#   Query 104 - 1. Doc[1449] Distance: 0.9100
#   Query 105 - 1. Doc[713] Distance: 0.8421
#   Query 106 - 1. Doc[701] Distance: 0.8328
#   Query 107 - 1. Doc[595] Distance: 0.7160
#   Query 108 - 1. Doc[1423] Distance: 0.8127
#   Query 109 - 1. Doc[345] Distance: 0.8740
#   Query 110 - 1. Doc[473] Distance: 0.8934
#   Query 111 - 1. Doc[484] Distance: 0.7480
#   Query 112 - 1. Doc[568] Distance: 0.8181
#
# Top-1 văn bản (Euclidean Distance):
#   Query 1 - 1. Doc[1003] Distance: 2.4495
#   Query 2 - 1. Doc[1003] Distance: 3.0000
#   Query 3 - 1. Doc[1003] Distance: 2.0000
#   Query 4 - 1. Doc[1003] Distance: 2.0000
#   Query 5 - 1. Doc[1003] Distance: 2.2361
#   Query 6 - 1. Doc[1003] Distance: 2.0000
#   Query 7 - 1. Doc[1003] Distance: 3.3166
#   Query 8 - 1. Doc[1003] Distance: 1.7321
#   Query 9 - 1. Doc[1003] Distance: 2.2361
#   Query 10 - 1. Doc[1003] Distance: 2.2361
#   Query 11 - 1. Doc[1003] Distance: 1.4142
#   Query 12 - 1. Doc[1003] Distance: 2.0000
#   Query 13 - 1. Doc[1003] Distance: 1.4142
#   Query 14 - 1. Doc[1003] Distance: 1.0000
#   Query 15 - 1. Doc[1003] Distance: 1.7321
#   Query 16 - 1. Doc[1003] Distance: 2.0000
#   Query 17 - 1. Doc[1003] Distance: 2.4495
#   Query 18 - 1. Doc[1003] Distance: 2.8284
#   Query 19 - 1. Doc[1003] Distance: 2.6458
#   Query 20 - 1. Doc[1003] Distance: 1.4142
#   Query 21 - 1. Doc[1003] Distance: 1.7321
#   Query 22 - 1. Doc[1003] Distance: 1.4142
#   Query 23 - 1. Doc[1003] Distance: 1.4142
#   Query 24 - 1. Doc[1003] Distance: 3.0000
#   Query 25 - 1. Doc[1003] Distance: 1.4142
#   Query 26 - 1. Doc[1099] Distance: 1.0000
#   Query 27 - 1. Doc[1003] Distance: 1.0000
#   Query 28 - 1. Doc[1003] Distance: 1.4142
#   Query 29 - 1. Doc[1003] Distance: 1.4142
#   Query 30 - 1. Doc[1003] Distance: 1.4142
#   Query 31 - 1. Doc[1003] Distance: 1.4142
#   Query 32 - 1. Doc[1003] Distance: 1.0000
#   Query 33 - 1. Doc[1003] Distance: 1.4142
#   Query 34 - 1. Doc[1003] Distance: 1.4142
#   Query 35 - 1. Doc[1003] Distance: 2.2361
#   Query 36 - 1. Doc[68] Distance: 3.8730
#   Query 37 - 1. Doc[1003] Distance: 3.8730
#   Query 38 - 1. Doc[1003] Distance: 3.4641
#   Query 39 - 1. Doc[1003] Distance: 4.2426
#   Query 40 - 1. Doc[1003] Distance: 1.7321
#   Query 41 - 1. Doc[1003] Distance: 4.2426
#   Query 42 - 1. Doc[1003] Distance: 2.6458
#   Query 43 - 1. Doc[1003] Distance: 3.4641
#   Query 44 - 1. Doc[1003] Distance: 3.7417
#   Query 45 - 1. Doc[1003] Distance: 3.3166
#   Query 46 - 1. Doc[1003] Distance: 4.0000
#   Query 47 - 1. Doc[1003] Distance: 2.8284
#   Query 48 - 1. Doc[1003] Distance: 4.6904
#   Query 49 - 1. Doc[1003] Distance: 3.4641
#   Query 50 - 1. Doc[1003] Distance: 5.0990
#   Query 51 - 1. Doc[1003] Distance: 3.8730
#   Query 52 - 1. Doc[1003] Distance: 2.0000
#   Query 53 - 1. Doc[1003] Distance: 3.1623
#   Query 54 - 1. Doc[1003] Distance: 2.6458
#   Query 55 - 1. Doc[1003] Distance: 2.0000
#   Query 56 - 1. Doc[1003] Distance: 2.6458
#   Query 57 - 1. Doc[1003] Distance: 5.0000
#   Query 58 - 1. Doc[1003] Distance: 5.0990
#   Query 59 - 1. Doc[1003] Distance: 5.4772
#   Query 60 - 1. Doc[1003] Distance: 7.4162
#   Query 61 - 1. Doc[1003] Distance: 5.2915
#   Query 62 - 1. Doc[1003] Distance: 5.7446
#   Query 63 - 1. Doc[1003] Distance: 6.4807
#   Query 64 - 1. Doc[1003] Distance: 4.4721
#   Query 65 - 1. Doc[1295] Distance: 4.4721
#   Query 66 - 1. Doc[1003] Distance: 4.7958
#   Query 67 - 1. Doc[1003] Distance: 9.8995
#   Query 68 - 1. Doc[1003] Distance: 5.4772
#   Query 69 - 1. Doc[1295] Distance: 7.3485
#   Query 70 - 1. Doc[1003] Distance: 7.4162
#   Query 71 - 1. Doc[1130] Distance: 6.0000
#   Query 72 - 1. Doc[1003] Distance: 6.4031
#   Query 73 - 1. Doc[1003] Distance: 5.0000
#   Query 74 - 1. Doc[1003] Distance: 5.1962
#   Query 75 - 1. Doc[1003] Distance: 4.8990
#   Query 76 - 1. Doc[1003] Distance: 4.4721
#   Query 77 - 1. Doc[1003] Distance: 5.4772
#   Query 78 - 1. Doc[1003] Distance: 5.0990
#   Query 79 - 1. Doc[1003] Distance: 5.2915
#   Query 80 - 1. Doc[54] Distance: 8.1240
#   Query 81 - 1. Doc[1322] Distance: 7.1414
#   Query 82 - 1. Doc[855] Distance: 9.5394
#   Query 83 - 1. Doc[1003] Distance: 6.9282
#   Query 84 - 1. Doc[1003] Distance: 5.2915
#   Query 85 - 1. Doc[1003] Distance: 7.9373
#   Query 86 - 1. Doc[1003] Distance: 7.4833
#   Query 87 - 1. Doc[1003] Distance: 7.4162
#   Query 88 - 1. Doc[1003] Distance: 4.0000
#   Query 89 - 1. Doc[1003] Distance: 5.9161
#   Query 90 - 1. Doc[1003] Distance: 8.6023
#   Query 91 - 1. Doc[1003] Distance: 8.1854
#   Query 92 - 1. Doc[1003] Distance: 6.0000
#   Query 93 - 1. Doc[1003] Distance: 7.4833
#   Query 94 - 1. Doc[1003] Distance: 4.1231
#   Query 95 - 1. Doc[530] Distance: 7.2801
#   Query 96 - 1. Doc[1003] Distance: 4.1231
#   Query 97 - 1. Doc[1279] Distance: 7.5498
#   Query 98 - 1. Doc[625] Distance: 7.4162
#   Query 99 - 1. Doc[1003] Distance: 6.4807
#   Query 100 - 1. Doc[1003] Distance: 4.2426
#   Query 101 - 1. Doc[1003] Distance: 6.4807
#   Query 102 - 1. Doc[573] Distance: 5.7446
#   Query 103 - 1. Doc[1003] Distance: 4.1231
#   Query 104 - 1. Doc[1003] Distance: 5.0990
#   Query 105 - 1. Doc[1003] Distance: 4.4721
#   Query 106 - 1. Doc[1003] Distance: 7.2801
#   Query 107 - 1. Doc[1003] Distance: 5.5678
#   Query 108 - 1. Doc[1003] Distance: 5.2915
#   Query 109 - 1. Doc[1301] Distance: 6.0000
#   Query 110 - 1. Doc[1003] Distance: 8.2462
#   Query 111 - 1. Doc[1003] Distance: 3.8730
#   Query 112 - 1. Doc[1003] Distance: 4.1231
#
# Top-1 văn bản (Manhattan Distance):
#   Query 1 - 1. Doc[1003] Distance: 6.0000
#   Query 2 - 1. Doc[1003] Distance: 9.0000
#   Query 3 - 1. Doc[1003] Distance: 4.0000
#   Query 4 - 1. Doc[1003] Distance: 4.0000
#   Query 5 - 1. Doc[1003] Distance: 5.0000
#   Query 6 - 1. Doc[1003] Distance: 4.0000
#   Query 7 - 1. Doc[1003] Distance: 11.0000
#   Query 8 - 1. Doc[1003] Distance: 3.0000
#   Query 9 - 1. Doc[1003] Distance: 5.0000
#   Query 10 - 1. Doc[1003] Distance: 5.0000
#   Query 11 - 1. Doc[1003] Distance: 2.0000
#   Query 12 - 1. Doc[1003] Distance: 4.0000
#   Query 13 - 1. Doc[1003] Distance: 2.0000
#   Query 14 - 1. Doc[1003] Distance: 1.0000
#   Query 15 - 1. Doc[1003] Distance: 3.0000
#   Query 16 - 1. Doc[1003] Distance: 4.0000
#   Query 17 - 1. Doc[1003] Distance: 6.0000
#   Query 18 - 1. Doc[1003] Distance: 8.0000
#   Query 19 - 1. Doc[1003] Distance: 5.0000
#   Query 20 - 1. Doc[1003] Distance: 2.0000
#   Query 21 - 1. Doc[1003] Distance: 3.0000
#   Query 22 - 1. Doc[1003] Distance: 2.0000
#   Query 23 - 1. Doc[1003] Distance: 2.0000
#   Query 24 - 1. Doc[1003] Distance: 7.0000
#   Query 25 - 1. Doc[1003] Distance: 2.0000
#   Query 26 - 1. Doc[1099] Distance: 1.0000
#   Query 27 - 1. Doc[1003] Distance: 1.0000
#   Query 28 - 1. Doc[1003] Distance: 2.0000
#   Query 29 - 1. Doc[1003] Distance: 2.0000
#   Query 30 - 1. Doc[1003] Distance: 2.0000
#   Query 31 - 1. Doc[1003] Distance: 2.0000
#   Query 32 - 1. Doc[1003] Distance: 1.0000
#   Query 33 - 1. Doc[1003] Distance: 2.0000
#   Query 34 - 1. Doc[1003] Distance: 2.0000
#   Query 35 - 1. Doc[1003] Distance: 5.0000
#   Query 36 - 1. Doc[68] Distance: 9.0000
#   Query 37 - 1. Doc[1003] Distance: 13.0000
#   Query 38 - 1. Doc[1003] Distance: 12.0000
#   Query 39 - 1. Doc[1003] Distance: 16.0000
#   Query 40 - 1. Doc[1003] Distance: 3.0000
#   Query 41 - 1. Doc[1003] Distance: 12.0000
#   Query 42 - 1. Doc[1003] Distance: 7.0000
#   Query 43 - 1. Doc[1003] Distance: 12.0000
#   Query 44 - 1. Doc[1003] Distance: 14.0000
#   Query 45 - 1. Doc[1003] Distance: 11.0000
#   Query 46 - 1. Doc[1003] Distance: 14.0000
#   Query 47 - 1. Doc[1003] Distance: 8.0000
#   Query 48 - 1. Doc[1003] Distance: 22.0000
#   Query 49 - 1. Doc[1003] Distance: 10.0000
#   Query 50 - 1. Doc[1003] Distance: 16.0000
#   Query 51 - 1. Doc[1003] Distance: 9.0000
#   Query 52 - 1. Doc[1003] Distance: 4.0000
#   Query 53 - 1. Doc[1003] Distance: 8.0000
#   Query 54 - 1. Doc[1003] Distance: 7.0000
#   Query 55 - 1. Doc[1003] Distance: 4.0000
#   Query 56 - 1. Doc[1003] Distance: 7.0000
#   Query 57 - 1. Doc[1003] Distance: 21.0000
#   Query 58 - 1. Doc[1003] Distance: 24.0000
#   Query 59 - 1. Doc[1003] Distance: 30.0000
#   Query 60 - 1. Doc[1003] Distance: 37.0000
#   Query 61 - 1. Doc[1003] Distance: 20.0000
#   Query 62 - 1. Doc[1003] Distance: 21.0000
#   Query 63 - 1. Doc[1003] Distance: 32.0000
#   Query 64 - 1. Doc[1003] Distance: 20.0000
#   Query 65 - 1. Doc[1295] Distance: 14.0000
#   Query 66 - 1. Doc[1003] Distance: 17.0000
#   Query 67 - 1. Doc[1003] Distance: 50.0000
#   Query 68 - 1. Doc[1003] Distance: 26.0000
#   Query 69 - 1. Doc[1295] Distance: 40.0000
#   Query 70 - 1. Doc[1003] Distance: 47.0000
#   Query 71 - 1. Doc[1003] Distance: 28.0000
#   Query 72 - 1. Doc[1003] Distance: 29.0000
#   Query 73 - 1. Doc[1003] Distance: 21.0000
#   Query 74 - 1. Doc[1003] Distance: 25.0000
#   Query 75 - 1. Doc[1003] Distance: 22.0000
#   Query 76 - 1. Doc[1003] Distance: 20.0000
#   Query 77 - 1. Doc[1003] Distance: 26.0000
#   Query 78 - 1. Doc[1003] Distance: 22.0000
#   Query 79 - 1. Doc[1003] Distance: 20.0000
#   Query 80 - 1. Doc[54] Distance: 48.0000
#   Query 81 - 1. Doc[1003] Distance: 32.0000
#   Query 82 - 1. Doc[855] Distance: 33.0000
#   Query 83 - 1. Doc[1003] Distance: 32.0000
#   Query 84 - 1. Doc[1003] Distance: 26.0000
#   Query 85 - 1. Doc[1003] Distance: 55.0000
#   Query 86 - 1. Doc[1003] Distance: 40.0000
#   Query 87 - 1. Doc[1003] Distance: 29.0000
#   Query 88 - 1. Doc[1003] Distance: 14.0000
#   Query 89 - 1. Doc[1003] Distance: 23.0000
#   Query 90 - 1. Doc[1003] Distance: 62.0000
#   Query 91 - 1. Doc[1003] Distance: 49.0000
#   Query 92 - 1. Doc[1003] Distance: 20.0000
#   Query 93 - 1. Doc[1003] Distance: 46.0000
#   Query 94 - 1. Doc[1003] Distance: 17.0000
#   Query 95 - 1. Doc[1003] Distance: 29.0000
#   Query 96 - 1. Doc[1003] Distance: 15.0000
#   Query 97 - 1. Doc[1279] Distance: 39.0000
#   Query 98 - 1. Doc[1295] Distance: 31.0000
#   Query 99 - 1. Doc[1003] Distance: 34.0000
#   Query 100 - 1. Doc[1003] Distance: 16.0000
#   Query 101 - 1. Doc[1003] Distance: 26.0000
#   Query 102 - 1. Doc[1003] Distance: 27.0000
#   Query 103 - 1. Doc[1003] Distance: 15.0000
#   Query 104 - 1. Doc[1003] Distance: 18.0000
#   Query 105 - 1. Doc[1003] Distance: 18.0000
#   Query 106 - 1. Doc[1003] Distance: 41.0000
#   Query 107 - 1. Doc[1003] Distance: 25.0000
#   Query 108 - 1. Doc[1003] Distance: 22.0000
#   Query 109 - 1. Doc[1301] Distance: 36.0000
#   Query 110 - 1. Doc[1003] Distance: 42.0000
#   Query 111 - 1. Doc[1003] Distance: 13.0000
#   Query 112 - 1. Doc[1003] Distance: 15.0000

# %% [markdown]
# # So sánh độ chính xác với thực tế với StopWords

# %%
compare_results_with_stopwords = compare_methods(cosine_results_with_stopwords, euclidean_results_with_stopwords, manhattan_results_with_stopwords)
# Out:
# COSINE:
#   Hits: 4/112
#   Accuracy: 3.57%
#
# EUCLIDEAN:
#   Hits: 1/112
#   Accuracy: 0.89%
#
# MANHATTAN:
#   Hits: 1/112
#   Accuracy: 0.89%
